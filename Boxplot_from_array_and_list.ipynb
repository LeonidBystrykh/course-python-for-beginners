# %% [markdown]
# I came to this unexpected results while explaining the transposition
# In a way this is useful feature, althout I do not understand how it works.
# First, we import the matplotlib.pyplot library.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Let's define some simple and short list of lists with integers. Also check the type by calling type() function

# %%
data=[[1,2,3,2,0],
     [2,3,1,4,5],
     [9,8,5,6,9]]
type(data)
# Out:
# list

# %% [markdown]
# It is a list. Lets make a boxplot from these data

# %%
plt.boxplot(data);

# %% [markdown]
# We have three boxplots for three lists of data. Everything seems as expected.
# Let's define the data as numpy array, and then ask for the boxplot

# %%
import numpy as np
plt.boxplot(np.array(data));

# %% [markdown]
# We have 5 boxes, as if we read the transposed lists. I hope someone will explain me how it works. I cannot.
# We can also check whether violinplot does the same thing.

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.violinplot(data);
plt.title("data as list")
plt.subplot(122)
plt.title("data as np.array")
plt.violinplot(np.array(data));

# %% [markdown]
# It works exactly the same way as boxplot
# Let's check the length of data in two different formats

# %%
print("len list data", len(data))
print("len array data", len(np.array(data)))
# Out:
# len list data 3
# len array data 3

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot([1,2,3],data);
plt.subplot(122)
plt.plot([1,2,3],np.array(data));

# %% [markdown]
# Scatter plot would not work in such design at all.
